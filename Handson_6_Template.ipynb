# %% [markdown]
# # Dictionaries
#
# To submit this assignment in D2l, post the link to your notebook file on your GitHub account.

# %% [markdown]
# ## 12.1 Champion Counter
# Create a program that reads a text file that contains a list of FIFA World Cup champions and determines the country that has won the most championships.
#
# ### Console:
# ```powershell
# Country	        Wins	Years
# =======	        ====	=====
# Argentina       2       1978, 1986
# Brazil	        5       1958, 1962, 1970, 1994, 2002
# England	        1       1966
# France	        1       1998
# Germany	        4       1954, 1974, 1990, 2014
# Italy	        4       1934, 1938, 1982, 2006
# Spain	        1       2010
# Uruguay	        2       1930, 1950
# ```
#
# ### Specifications:
# - Use the attached text file named `world_cup_champions.txt` that contains data like this:
# ```powershell
# Year,Country,Coach,Captain
# 1930,Uruguay,Alberto Suppici,José Nasazzi
# 1934,Italy,Vittorio Pozzo,Gianpiero Combi
# 1938,Italy,Vittorio Pozzo,Giuseppe Meazza
# ...
# ```
# - When the program starts, it should read the text file and use a dictionary to store the required data using the name of each country that has won the World Cup as the key.
# - The program should compile the data shown above and display the countries alphabetically.

# %%
import os

def main():
    filename = "world_cup_champions.txt"
    if not os.path.exists(filename):
        print("Error: world_cup_champions.txt not found.")
        return

    champions_data = {}
    with open(filename, "r") as file:
        file.readline()
        for line in file:
            parts = line.strip().split(",")
            
            year = parts[0]
            country = parts[1]
            
            if country not in champions_data:
                champions_data[country] = []
            champions_data[country].append(year)

    print("Country\t\tWins\tYears")
    print("=======\t\t====\t=====")


    alphabetical_countries = sorted(champions_data.keys())
    
    for country in alphabetical_countries:
        years_list = champions_data[country]
        wins = len(years_list)
        years_str = ", ".join(years_list)
        if len(country) < 8:
            print(country + "\t\t" + str(wins) + "\t" + years_str)
        else:
            print(country + "\t" + str(wins) + "\t" + years_str)

if __name__ == "__main__":
    main()
# Out:
# Country		Wins	Years
# =======		====	=====
# Argentina	2	1978, 1986
# Brazil		5	1958, 1962, 1970, 1994, 2002
# England		1	1966
# France		1	1998
# Germany		4	1954, 1974, 1990, 2014
# Italy		4	1934, 1938, 1982, 2006
# Spain		1	2010
# Uruguay		2	1930, 1950

# %% [markdown]
# ## 12.2 Monthly Sales
# Create a program that allows you to view and edit the sales amounts for each month of the current year.
#
# ### Console:
# ```powershell
# Monthly Sales program
#
# COMMAND MENU
# view	- View sales for specified month
# edit	- Edit sales for specified month
# totals - View sales summary for year
# exit	- Exit program
#
# Command: view
# Three-letter Month: jan
# Sales amount for Jan is 14,317.00.
#
# Command: edit
# Three-letter Month: jan
# Sales Amount: 15293
# Sales amount for Jan is 15,293.00.
#
# Command: totals
# Yearly total: 67,855.00
# Monthly average: 5,654.58
#
# Command: view
# Three-letter Month: july
# Invalid three-letter month.
#
# Command: exit Bye!
# ```
#
# ### Specifications:
# - Use the attached text file named `monthly_sales.txt` that consists of rows that contain three-letter abbreviations for the month and the monthly sales.
# - The program should read the file and store the sales data for each month in a dictionary with the month abbreviation as the key for each item.
# - Whenever the sales data is edited, the program should write the changed data to the text file.

# %%
import os

def main():
    filename = "monthly_sales.txt"
    sales_data = {}
    
    if not os.path.exists(filename):
        print("Error: monthly_sales.txt not found.")
        return

    file = open(filename, "r")
    for line in file:
        line = line.strip()
        if line == "":
            continue
        if "," in line:
            parts = line.split(",")
        else:
            parts = line.split()
        
        if len(parts) >= 2:
            month = parts[0].strip().lower()
            amount = float(parts[1])
            sales_data[month] = amount
    file.close()

    print("Monthly Sales program")
    print("")
    print("COMMAND MENU")
    print("view   - View sales for specified month")
    print("edit   - Edit sales for specified month")
    print("totals - View sales summary for year")
    print("exit   - Exit program")

    while True:
        print("")
        command = input("Command: ").strip().lower()
        if command == "view":
            month_input = input("Three-letter Month: ").strip().lower()
            if month_input in sales_data:
                amount = sales_data[month_input]
                print("Sales amount for " + month_input.capitalize() + " is " + format(amount, ",.2f") + ".")
            else:
                print("Invalid three-letter month.")

        elif command == "edit":
            month_input = input("Three-letter Month: ").strip().lower()
            if month_input in sales_data:
                new_amount = float(input("Sales Amount: "))
                sales_data[month_input] = new_amount
                
                file = open(filename, "w")
                for m in sales_data:
                    file.write(m.capitalize() + "," + str(sales_data[m]) + "\n")
                file.close()
                
                print("Sales amount for " + month_input.capitalize() + " is " + format(new_amount, ",.2f") + ".")
            else:
                print("Invalid three-letter month.")

        elif command == "totals":
            total = 0.0
            for m in sales_data:
                total = total + sales_data[m]
            
            count = len(sales_data)
            if count > 0:
                average = total / count
                print("Yearly total:     " + format(total, ",.2f"))
                print("Monthly average:  " + format(average, ",.2f"))
            else:
                print("No data available.")

        elif command == "exit":
            print("Bye!")
            break
        else:
            print("Invalid command.")

if __name__ == "__main__":
    main()
# Out:
# Monthly Sales program
#
# COMMAND MENU
# view   - View sales for specified month
# edit   - Edit sales for specified month
# totals - View sales summary for year
# exit   - Exit program
# Command:  view
# Three-letter Month:  dec
# Sales amount for Dec is 15,000.00.
# Command:  edit
# Three-letter Month:  sep
# Sales Amount:  2345
# Sales amount for Sep is 2,345.00.
# Command:  totals
# Yearly total:     79,290.00
# Monthly average:  6,607.50
# Command:  exit
# Bye!
